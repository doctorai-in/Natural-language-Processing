# %% [markdown]
# # Building a Conversational Chatbot using Rasa and Python
#
# ---

# %% [markdown]
# <b>Issue</b>: In many cases, Clients do not want to share their data and since  majority of the avialable tools are cloud-based and provide software as a service so you can not run them internally in your environment and you need to send your data to the third party.
#
# <b>Solution</b> : With <b>RASA stack</b> an open-source customizable AI tool there is no such issue. You can build, deploy or host Rasa internally in your server or environment with complete control on it.
#
# Rasa comes up with 2 components —
#
# <b>Rasa NLU:</b> NLU deals with teaching a chatbot on how to understand user inputs.<br>
# <b>Rasa Core:</b> Deals with teaching a chatbot on how to respond to user’s query.

# %% [markdown]
# ![Screenshot (119).png](data:image/png;base64,...)

# %% [markdown]
# # Customization for training own models

# %% [markdown]
# ![Screenshot (117).png](data:image/png;base64,...)

# %% [markdown]
# ## Starting Jupyter Notebook with necessary imports

# %%
# !pip install rasa==1.10.3

# %%
# !python -m spacy download en

# %%
#!pip install nest_asyncio==1.3.3

# %%
import os
import rasa
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %% [markdown]
# # creating project

# %%
from rasa.cli.scaffold import create_initial_project

# %%
project = "Safety-Chatbot-Oil-and-Gas-Industry"
create_initial_project(project)

# %%
# move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ['credentials.yml', 'domain.yml', 'config.yml', 'tests', '__pycache__', 'endpoints.yml', 'data', 'actions.py', '__init__.py']

# %%
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %% [markdown]
# ### Sometime it may not run on first go. So, try to execute below line 3 time and it work fine. It is bug in rasa.

# %%
model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# Training Core model...
# ...
# Processed trackers: 100%|██████████| 5/5 [00:00<00:00, 78.29it/s, # actions=16]
# Processed actions: 16it [00:00, 609.35it/s, # examples=16]
# Processed trackers: 100%|██████████| 231/231 [00:09<00:00, 25.40it/s, # actions=126]
# WARNING:tensorflow:AutoGraph could not transform <bound method RasaModel.train_on_batch of <rasa.core.policies.ted_policy.TED object at 0x7ff78ea5cc10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Num'
# WARNING: AutoGraph could not transform <bound method RasaModel.train_on_batch of <rasa.core.policies.ted_policy.TED object at 0x7ff78ea5cc10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# ...

# %%
from rasa.jupyter import chat
 
endpoints = 'endpoints.yml'

# %%
chat(model_path, endpoints)

# %%
# %%writefile data/nlu.md
#
#
# ## intent:safety_standards
# - What the safety managments for oil refinery?
# - safety steps invovled in oil refinery?
# - can you tell how to maintain safety in refining of oil?
# - Is there any safety managemet system in oil refining?
#
# ## intent:Process_Safety_Information
# - What is Process Safety Information?
# - how we can measure Process Safety Information?
# - can you tell me about Process Safety Information?
# - may i know about Process Safety Information?
#
# ## intent:RAGAGEP
# - What is Process RAGAGEP?
# - Procedure of RAGAGEP?
# - can you tell me about RAGAGEP?
# - may i know about Process RAGAGEP?
#
# ## intent:Piping_and_Instrumentation_Diagrams
# - What is Piping and Instrumentation Diagrams?
# - can you tell me about Piping and Instrumentation Diagrams?
# - Piping and Instrumentation Diagrams?
# - Is there any Piping and Instrumentation Diagrams?
# - Piping and Instrumentation Diagrams in oil refining?
#
# ## intent:Relief_System_Design_and_Design_Basis
# - What is Relief_System_Design_and_Design_Basis?
# - can you tell me about Relief_System_Design_and_Design_Basis?
# - Relief_System_Design_and_Design_Basis?
#
#
#
# ## intent:Process_Hazards_Analysis
# - What is Process_Hazards_Analysis?
# - how does Process_Hazards_Analysis can be done?
# - Process_Hazards_Analysis?
# - can you tell me about Process_Hazards_Analysis?
#
# ## intent:Operating_Procedures
# - What are Operating_Procedures?
# - Is there any Operating_Procedures?
# - can you tell me Operating_Procedures?
# - Operating_Procedures ?
# - what is the Operating_Procedures?
#
# ## intent:Mechanical_Integrity
# - What is the Mechanical_Integrity?
# - Is there any Mechanical_Integrity?
# - Mechanical_Integrity?
# - can you tell me about Mechanical_Integrity?
#
# ## intent:Management_of_Change
# - What is the Management_of_Change?
# - Management_of_Change?
# - can you tell me about Management_of_Change?
#
#
# ## intent:greet
# - hey
# - hello
# - hi
# - good morning
# - good evening
# - hey there
#
# ## intent:goodbye
# - bye
# - goodbye
# - see you around
# - see you later
#
# ## intent:affirm
# - yes
# - indeed
# - of course
# - that sounds good
# - correct
#
# ## intent:deny
# - no
# - never
# - I don't think so
# - don't like that
# - no way
# - not really
#
# ## intent:mood_great
# - perfect
# - very good
# - great
# - amazing
# - wonderful
# - I am feeling very good
# - I am great
# - I'm good
#
# ## intent:mood_unhappy
# - sad
# - very sad
# - unhappy
# - bad
# - very bad
# - awful
# - terrible
# - not very good
# - extremely sad
# - so sad
#
# ## intent:bot_challenge
# - are you a bot?
# - are you a human?
# - am I talking to a bot?
# - am I talking to a human?
# Out:
# Overwriting data/nlu.md

# %%
# %%writefile domain.yml
#
# intents:
#   - greet
#   - goodbye
#   - affirm
#   - deny
#   - mood_great
#   - mood_unhappy
#   - bot_challenge
#   - Management_of_Change
#   - safety_standards
#   - Process_Safety_Information
#   - RAGAGEP
#   - Piping_and_Instrumentation_Diagrams
#   - Relief_System_Design_and_Design_Basis
#   - Process_Hazards_Analysis
#   - Operating_Procedures
#   - Mechanical_Integrity
#
# responses:
#
#   utter_Piping_and_Instrumentation_Diagrams:
#   - text: "The PSM standard requires employers to maintain piping and instrumentation diagrams (P&IDs). \n P&IDs show the interconnection of process equipment, the instrumentation used to control the process, and they provide engineers, operators, and maintenance employees with information on how to maintain and modify the process. \n  P&IDs must accurately demonstrate the physical sequence of equipment and systems, and how these systems are connected. \n  Without accurate, complete, and up-to-date P&IDs, engineers and operators can be misinformed.\n During NEP inspections, OSHA cited several instances where petroleum refineries did not check to ensure that tags on their equipment matched what was written in the P&ID, or that all P&IDs at a facility shared the same notation system. Such errors and inconsistencies may lead to confusion or an incident when maintaining or repairing process equipment. An example of an industry practice notation system that employers can use is the Instrumentation, Systems, and Automation Society’s (ISA) ANSI/ ISA-S5.1 Instrumentation Symbols and Identification American National Standard. When OSHA found P&ID deficiencies, such as those identified above, the problems were frequently systemic and encompassed many of these deficiencies. Failure to ensure the accuracy of facility P&IDs may also indicate problems with the employer’s Management of Change program. During NEP inspections, OSHA cited several instances where petroleum refineries did not check to ensure that tags on their equipment matched what was written in the P&ID, or that all P&IDs at a facility shared the same notation system. Such errors and inconsistencies may lead to confusion or an incident when maintaining or repairing process equipment. An example of an industry practice notation system that employers can use is the Instrumentation, Systems, and Automation Society’s (ISA) ANSI/ ISA-S5.1 Instrumentation Symbols and Identification American National Standard. When OSHA found P&ID deficiencies, such as those identified above, the problems were frequently systemic and encompassed many of these deficiencies. Failure to ensure the accuracy of facility P&IDs may also indicate problems with the employer’s Management of Change program. During NEP inspections, OSHA cited several instances where petroleum refineries did not check to ensure that tags on their equipment matched what was written in the P&ID, or that all P&IDs at a facility shared the same notation system. \n Such errors and inconsistencies may lead to confusion or an incident when maintaining or repairing process equipment. \n An example of an industry practice notation system that employers can use is the Instrumentation, Systems, and Automation Society’s (ISA) ANSI/ ISA-S5.1 Instrumentation Symbols and Identification American National Standard. When OSHA found P&ID deficiencies, such as those identified above, the problems were frequently systemic and encompassed many of these deficiencies. \n Failure to ensure the accuracy of facility P&IDs may also indicate problems with the employer’s Management of Change program. \n During NEP inspections, OSHA cited several instances where petroleum refineries did not check to ensure that tags on their equipment matched what was written in the P&ID, or that all P&IDs at a facility shared the same notation system. \n Such errors and inconsistencies may lead to confusion or an incident when maintaining or repairing process equipment. \n An example of an industry practice notation system that employers can use is the Instrumentation, Systems, and Automation Society’s (ISA) ANSI/ ISA-S5.1 Instrumentation Symbols and Identification American National Standard. \n When OSHA found P&ID deficiencies, such as those identified above, the problems were frequently systemic and encompassed many of these deficiencies. \n Failure to ensure the accuracy of facility P&IDs may also indicate problems with the employer’s Management of Change program."
#
#   utter_Relief_System_Design_and_Design_Basis:
#   - text: "The PSI provisions of the standard require employers to keep accurate, complete, and up-to-date documentation of relief system design and design basis. \n It is important that a facility can demonstrate, in writing, why a relief system was designed in the selected manner. \n With this information employees remain informed of current relief design systems and any future changes to an associated process can be made appropriately. \n OSHA found that many refineries did not have this documentation. Potential sources of guidance for relief system design can be found in API 520: Sizing, Selection, and Installation of Pressure-Relieving Devices in Refineries and/or Chemical Center for Process Safety (CCPS) Guidelines for Pressure Relief and Effluent Handling Systems, 2nd Edition. \n Additionally, a potential source of guidance on relief system design basis is API 521: Pressure-relieving and Depressuring Systems.."
#
#   utter_Process_Hazards_Analysis:
#   - text: "A process hazard analysis (PHA) is an organized and systematic effort to identify and analyze the significance of potential hazards associated with the processing and handling of HHC. \n The PHA must be appropriate to the complexity of the process and must identify, evaluate, and control the hazards involved in the process. \n The PHA team may make recommendations for additional safeguards to adequately control identified hazards or to mitigate their effects, or these may be generated by post-PHA evaluations of the team’s findings.  Safeguards may include inherently safer or passive approaches to hazard control, new engineering controls (e.g., improved fire detection and suppression systems) or administrative controls (e.g., new operating procedures, inventory control measures, or separation of HHC into different storage areas). During NEP inspections, OSHA frequently found PHA deficiencies in \n (1) recommendation resolution, \n (2) facility siting, \n (3) human factors analyses."
#
#   utter_Operating_Procedures:
#   - text: "PSM-covered petroleum refineries are required to develop and implement written operating procedures that provide clear instructions for safely conducting activities involved in each covered process consistent with the process safety information. \n  Operating procedures must provide clear instructions not only to specify the steps for normal operations, but also for upset conditions, temporary operations, safe work practices, and emergency shutdown. \n  Operating procedures must address the basic hazards that are or could be encountered in the process.25 During NEP inspections, many operating procedures citations resulted from a complete absence of written operating procedures.\n However, even when operating procedures existed, OSHA found that they were not always accurate or implemented as written.\n Over the lifetime of a unit, operating activities may begin to deviate from the original written procedure. Sometimes deviations can produce the desired result, other times it can place workers in hazardous conditions. During NEP inspections, OSHA found many instances where operators deviated from the written operating procedures. \n To prevent this, management and operators should meet to review the effectiveness of existing procedures, and revise them as necessary. A strong employee participation plan can facilitate this interaction. \n Operators are often the first to realize when a procedure is unrealistic or unattainable, \n but they must be encouraged to approach management and technical staff with these issues instead of finding their own creative, and potentially dangerous, solutions.  Regardless, employers must periodically review operating procedures and certify them annually CCPS also recommends that employers consider using event-based review periods – such as reviewing shutdown procedures prior to a planned turnaround, and using lessons learned from recent significant events – rather than waiting until the next review cycle."
#
#   utter_Mechanical_Integrity:
#   - text: "The Mechanical Integrity (MI) element of the PSM Standard requires employers to create written procedures to maintain the ongoing integrity of process equipment, train for process maintenance activities, inspect and test process equipment, correct equipment deficiencies, and perform quality assurance. \n MI programs must address pressure vessels, storage tanks, piping systems (including piping components such as valves), pumps, relief and vent systems and devices, emergency shutdown systems, and controls (including monitoring devices and sensors, alarms, and interlocks) During NEP inspections, OSHA found MI compliance issues, including \n (1) equipment deficiencies, \n (2) inspection, testing, and maintenance procedures, \n (3) resolving anomalous data, \n (4) ensuring site-specific inspection and testing. ."
#
#   utter_safety_standards:
#   - text: "Process Safety Information (PSI),  \n Process Hazards Analysis (PHA), Operating Procedures, Mechanical Integrity (MI), Management of Change (MOC)."
#
#   utter_Process_Safety_Information:
#   - text: "Employers are required to compile written process safety information (PSI). \n The compilation of written process safety information enables the employer and the employees involved in operating the process to identify and understand the hazards posed by those processes involving HHC. \n Process safety information must include information pertaining to the hazards of the HHC used or produced by the process, \n information pertaining to the technology of the process, and information pertaining to the equipment in the process. \n Complete and accurate compilation of PSI is critical to the effective implementation of all other aspects of the PSM. \n PSI provisions of the standard also require that all equipment in PSM-covered processes comply with recognized and generally accepted good engineering practices (RAGAGEP). \n The PSM standard allows employers to select the RAGAGEP they apply in their covered processes. \n Examples of RAGAGEP include widely adopted codes, consensus documents, non-consensus documents, and internal standards Furthermore, where the design codes, standards, or practices used in the design and construction of existing equipment are no longer in general use, the employer must determine and document that the equipment is designed, maintained, inspected, tested, and operating in a safe manner. \n Regarding the PSI element, during inspections under the NEP OSHA issued many citations for violations of the PSM standard related to \n (1) RAGAGEP, \n (2) piping & instrumentation diagrams (P&IDs), \n (3) relief system design basis "
#
#   utter_RAGAGEP:
#   - text: "A. Relief Systems RAGAGEP \n API 520: Sizing, Selection, and Installation of Pressure-Relieving Devices in Refineries is an example of a RAGAGEP often used in petroleum refineries. API 520 covers appropriate relief system size calculations based on process parameters such as flow rate and pressure. API 520 also provides information on how to maintain appropriate back pressure on relief valves. According to API 520, a symptom of relief valves with excessive back pressure is fluttering or chattering of the valve. Chattering may affect the integrity of the relief device and interconnected piping, as well as reduce relief capacity. \n Additionally, the Chemical Center for Process Safety (CCPS) recommends reviewing completed lockout permits to identify conditions that do not appear to be appropriate (such as an intervening valve remaining closed, or not verified re-opened), or identifying persons authorizing permits or doing work who do not effectively understand how to authorize or conduct nonroutine work . \n B. Facility Siting RAGAGEP \n a) Select a credible release scenario11 which refiners should not change unless the employer can reasonably demonstrate that the original scenario was unrealistic; \n b) Model the release and consequences \n c) Locate personnel away from process areas consistent with safe and effective operations; \n d) Minimize the use of buildings intended for occupancy in close proximity to process areas; \n e) Restrict the occupancy of buildings in close proximity to process areas; \n f) Design, construct, install, modify, and maintain buildings intended for occupancy to protect occupants against explosion, fire, and toxic material releases; \n g) Manage the use of buildings intended for occupancy as an integral part of the design, construction, maintenance, and operation of a facility"
#
#   utter_Management_of_Change:
#   - text:"The Management of Change (MOC) section of the PSM standard requires the employer to implement written procedures to manage changes (except for “replacements in kind”) to process chemicals, technology, equipment, procedures, and changes to facilities that affect a covered process.\n The MOC procedure requires descriptions of the technical basis for the change,58 impact on safety and health, modifications to operating procedures,  necessary time period for change, and appropriate authorizations.\n Any employee who will be impacted by the change must be informed and trained appropriately before the unit/process can restart.63 During NEP inspections, OSHA found MOC non-compliance for changes in \n (1) equipment design,\n (2) operating procedure,\n (3) regular maintenance/repair, \n (4) facilities, \n (5) excessive time limits for temporary changes."
#
#
#   utter_greet:
#   - text: "Hey! How may i help you?"
#
#   utter_cheer_up:
#   - text: "Here is something to cheer you up:"
#     image: "https://i.imgur.com/nGF1K8f.jpg"
#
#   utter_did_that_help:
#   - text: "Did that help you?"
#
#   utter_happy:
#   - text: "Great, carry on!"
#
#   utter_goodbye:
#   - text: "Bye"
#
#   utter_iamabot:
#   - text: "I am a bot, powered by Rasa."
#
# entities:
#   - number
#
# session_config:
#   session_expiration_time: 60
#   carry_over_slots_to_new_session: true
# Out:
# Overwriting domain.yml

# %%
# %%writefile data/stories.md
#
# ## safety_standards
# * greet
#   - utter_greet
# * safety_standards
#   - utter_safety_standards
#
# ## Process_Safety_Information
# * greet
#   - utter_greet
# * Process_Safety_Information
#   - utter_Process_Safety_Information
#
# ## RAGAGEP
# * greet
#   - utter_greet
# * RAGAGEP
#   - utter_RAGAGEP
#
# ## Piping_and_Instrumentation_Diagrams
# * greet
#   - utter_greet
# * Piping_and_Instrumentation_Diagrams
#   - utter_Piping_and_Instrumentation_Diagrams
#
#
# ## Relief_System_Design_and_Design_Basis
# * greet
#   - utter_greet
# * Relief_System_Design_and_Design_Basis
#   - utter_Relief_System_Design_and_Design_Basis
#
# ## Process_Hazards_Analysis
# * greet
#   - utter_greet
# * Process_Hazards_Analysis
#   - utter_Process_Hazards_Analysis
#
# ## Operating_Procedures
# * greet
#   - utter_greet
# * Operating_Procedures
#   - utter_Operating_Procedures
#
# ## Mechanical_Integrity
# * greet
#   - utter_greet
# * Mechanical_Integrity
#   - utter_Mechanical_Integrity
#
# ## Management_of_Change
# * greet
#   - utter_greet
# * Management_of_Change
#   - utter_Management_of_Change
#
#
#
#
# ## happy path
# * greet
#   - utter_greet
# * mood_great
#   - utter_happy
#
# ## sad path 1
# * greet
#   - utter_greet
# * mood_unhappy
#   - utter_cheer_up
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## sad path 2
# * greet
#   - utter_greet
# * mood_unhappy
#   - utter_cheer_up
#   - utter_did_that_help
# * deny
#   - utter_goodbye
#
# ## say goodbye
# * goodbye
#   - utter_goodbye
#
# ## bot challenge
# * bot_challenge
#   - utter_iamabot
# Out:
# Overwriting data/stories.md

# %%
model_path =  rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/rasa/core/domain.py:137: FutureWarning: Templates should not be strings anymore. Utterance template 'utter_Management_of_Change' should contain either a '- text: ' or a '- custom: ' attribute to be a proper template.
#   utter_templates = cls.collect_templates(data.get("responses", {}))
# ...
# Processed Story Blocks:   0%|          | 0/14 [00:00<?, ?it/s, # trackers=14]
# Training Core model...
# ...
# Processed trackers: 100%|██████████| 14/14 [00:00<00:00, 101.53it/s, # actions=34]
# Processed actions: 34it [00:00, 565.52it/s, # examples=34]
# Processed trackers: 100%|██████████| 514/514 [00:23<00:00, 22.17it/s, # actions=438]
# WARNING:tensorflow:AutoGraph could not transform <bound method RasaModel.train_on_batch of <rasa.core.policies.ted_policy.TED object at 0x7ff785c32790>> and will run it as-is.
# ...

# %%
endpoints = "endpoints.yml"
chat(model_path, endpoints)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method DIET.batch_predict of <rasa.nlu.classifiers.diet_classifier.DIET object at 0x7ff785c15490>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Num'
# WARNING: AutoGraph could not transform <bound method DIET.batch_predict of <rasa.nlu.classifiers.diet_classifier.DIET object at 0x7ff785c15490>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:AutoGraph could not transform <bound method DenseForSparse.call of <rasa.utils.tensorflow.layers.DenseForSparse object at 0x7ff785b683d0>> and will run it as-is.
# ...

# %%
chat(model_path, endpoints)

# %%
# %%bash
# ZIP_FILE=/content/Safety-Chatbot-Oil-and-Gas-Industry.zip
# SOURCE=/content/Safety-Chatbot-Oil-and-Gas-Industry
# zip -r ${ZIP_FILE} ${SOURCE}
# Out:
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/ (stored 0%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/credentials.yml (deflated 48%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/domain.yml (deflated 69%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/config.yml (deflated 53%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/tests/ (stored 0%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/tests/conversation_tests.md (deflated 65%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/__pycache__/ (stored 0%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/__pycache__/__init__.cpython-37.pyc (deflated 23%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/__pycache__/actions.cpython-37.pyc (deflated 20%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/endpoints.yml (deflated 57%)
# updating: content/Safety-Chatbot-Oil-and-Gas-Industry/data/ (stored 0%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# ZIP_FILE=/content/Safety-Chatbot-Oil-and-Gas-Industry.zip
# PROJECT=OIL-AND-GAS-SAFETY-CHATBOT
# VERSION=1
# SAVE_TO_DRIVE=/content/drive/MyDrive/rasa-chatbot/${VERSION}/${PROJECT}/
# mkdir -p ${SAVE_TO_DRIVE}
# cp  -r ${ZIP_FILE} ${SAVE_TO_DRIVE}
